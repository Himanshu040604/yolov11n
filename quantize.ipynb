# %%
import os
# Allow duplicate OpenMP runtimes so torch won’t segfault
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
print("Set KMP_DUPLICATE_LIB_OK =", os.environ["KMP_DUPLICATE_LIB_OK"])
# Out:
# Set KMP_DUPLICATE_LIB_OK = TRUE

# %%
import os
import torch
from ultralytics import YOLO

FP32_CKPT  = 'outputs/cars_cosine_run2/weights/best.pt'
OUT_DIR    = 'quantized_model'
FP16_STATE = os.path.join(OUT_DIR, 'best_fp16.pth')

os.makedirs(OUT_DIR, exist_ok=True)

print(f"Loading FP32 checkpoint from {FP32_CKPT}...")
model = YOLO(FP32_CKPT)

print("Casting model to FP16...")
model.model.half()

print(f"Saving FP16 state_dict to {FP16_STATE}...")
torch.save(model.model.state_dict(), FP16_STATE)

print("✅ Finished.  You can now load with model.model.load_state_dict(...) and model.model.half().")
# Out:
# Loading FP32 checkpoint from outputs/cars_cosine_run2/weights/best.pt...
# Casting model to FP16...
# Saving FP16 state_dict to quantized_model\best_fp16.pth...
# ✅ Finished.  You can now load with model.model.load_state_dict(...) and model.model.half().

# %%
import os
import cv2
import time
import psutil
import torch
import numpy as np
from ultralytics import YOLO
import glob

# ─── CONFIG ─────────────────────────────────────────────────────────────────────────────
BASE_DIR        = os.getcwd()
VIDEO_IN        = os.path.join(BASE_DIR, 'dataset', 'test.mp4')
VIDEO_OUT       = os.path.join(BASE_DIR, 'outputs', 'detected_cars_fp16.mp4')
COMPILED_OUT    = os.path.join(BASE_DIR, 'outputs', 'compiled_video.mp4')
FRAMES_DIR      = os.path.join(BASE_DIR, 'FRAMES')
CHECKPT         = os.path.join(BASE_DIR, 'outputs', 'cars_cosine_run2', 'weights', 'best.pt')

os.makedirs(os.path.dirname(VIDEO_OUT), exist_ok=True)
os.makedirs(os.path.dirname(COMPILED_OUT), exist_ok=True)
os.makedirs(FRAMES_DIR, exist_ok=True)

# ─── 1) LOAD & CAST TO FP16 ─────────────────────────────────────────────────────────────
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Running on {device}")

yolo = YOLO(CHECKPT).to(device).half()
yolo.model.eval()

# ─── 2) VIDEO I/O ───────────────────────────────────────────────────────────────────────
cap = cv2.VideoCapture(VIDEO_IN)
if not cap.isOpened():
    raise FileNotFoundError(f"Cannot open {VIDEO_IN}")

fps = cap.get(cv2.CAP_PROP_FPS) or 20
w, h = 640, 320

fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out    = cv2.VideoWriter(VIDEO_OUT, fourcc, fps, (w, h))

# ─── 3) ENTRY/EXIT LINES ─────────────────────────────────────────────────────────────────
line_y    = int(h * 0.75)
red_off   = 20
blue_off  = 0
red_line  = [(int(0.55*w), line_y + red_off), (int(0.95*w), line_y + red_off)]
blue_line = [(int(0.10*w), line_y + blue_off), (int(0.50*w), line_y + blue_off)]

# ─── 4) TRACKERS & COUNTERS ──────────────────────────────────────────────────────────────
entry_count   = 0
exit_count    = 0
next_e_id     = 0
next_x_id     = 0
e_tracker     = {}
x_tracker     = {}
prev_centers  = []

# ─── 5) MONITORING SETUP ─────────────────────────────────────────────────────────────────
proc        = psutil.Process(os.getpid())
torch.cuda.reset_peak_memory_stats()
start_time  = time.time()
frame_idx   = 0

# ─── 6) MAIN LOOP ─────────────────────────────────────────────────────────────────────────
while True:
    ret, frame0 = cap.read()
    if not ret:
        break

    frame = cv2.resize(frame0, (w, h))

    # inference (prints per-frame timing)
    results = yolo(frame, conf=0.3, device=device)[0]

    dets = []
    for box in results.boxes:
        if int(box.cls) != 0:
            continue
        x1, y1, x2, y2 = box.xyxy[0].cpu().numpy().astype(int)
        cx, cy        = (x1 + x2)//2, (y1 + y2)//2
        prev          = next(
            (pc for pc in prev_centers
             if np.hypot(cx-pc[0], cy-pc[1]) < 50),
            None
        )
        dets.append({'box':(x1,y1,x2,y2),'curr':(cx,cy),'prev':prev})

    # entry logic
    for d in dets:
        cx, cy, pc = *d['curr'], d['prev']
        eid = next(
            (i for i, td in e_tracker.items()
             if np.hypot(cx-td['curr'][0], cy-td['curr'][1]) < 50),
            None
        )
        if eid is None and pc and pc[1] < red_line[0][1] <= cy:
            eid = next_e_id; next_e_id += 1
            e_tracker[eid] = {'prev':pc,'curr':(cx,cy),'counted':False}
        elif eid is not None:
            e_tracker[eid].update(prev=e_tracker[eid]['curr'], curr=(cx,cy))
        if eid is not None:
            td = e_tracker[eid]
            if not td['counted'] and td['prev'][1] < red_line[0][1] <= td['curr'][1]:
                entry_count += 1
                td['counted'] = True

    # exit logic
    for d in dets:
        cx, cy, pc = *d['curr'], d['prev']
        xid = next(
            (i for i, td in x_tracker.items()
             if np.hypot(cx-td['curr'][0], cy-td['curr'][1]) < 50),
            None
        )
        if xid is None and pc and pc[1] > blue_line[0][1] >= cy:
            xid = next_x_id; next_x_id += 1
            x_tracker[xid] = {'prev':pc,'curr':(cx,cy),'counted':False}
        elif xid is not None:
            x_tracker[xid].update(prev=x_tracker[xid]['curr'], curr=(cx,cy))
        if xid is not None:
            td = x_tracker[xid]
            if not td['counted'] and td['prev'][1] > blue_line[0][1] >= td['curr'][1]:
                exit_count += 1
                td['counted'] = True

    # draw
    for d in dets:
        x1,y1,x2,y2 = d['box']
        cv2.rectangle(frame, (x1,y1), (x2,y2), (0,255,0), 1)
    cv2.line(frame, *red_line,  (0,0,255), 2)
    cv2.line(frame, *blue_line, (255,0,0), 2)
    cv2.putText(frame, f"Cars: {len(dets)}",         (10,30),
                cv2.FONT_HERSHEY_SIMPLEX,0.7,(255,255,255),2)
    cv2.putText(frame, f"Entry(red): {entry_count}", (10,60),
                cv2.FONT_HERSHEY_SIMPLEX,0.7,(0,0,255),2)
    cv2.putText(frame, f"Exit(blue): {exit_count}",  (10,90),
                cv2.FONT_HERSHEY_SIMPLEX,0.7,(255,0,0),2)

    # save frame & write to output
    cv2.imwrite(os.path.join(FRAMES_DIR, f'frame_{frame_idx:05d}.png'), frame)
    out.write(frame)

    prev_centers = [d['curr'] for d in dets]
    frame_idx   += 1

# ─── 7) CLEANUP & SUMMARY ───────────────────────────────────────────────────────────────
cap.release()
out.release()
total_time = time.time() - start_time
print(f"✅ Done: {frame_idx} frames in {total_time:.1f}s → {frame_idx/total_time:.1f} FPS")
print(f"Final counts → Entry: {entry_count}, Exit: {exit_count}")

# ─── 8) COMPILE FRAMES INTO VIDEO ─────────────────────────────────────────────────────────
frame_files = sorted(glob.glob(os.path.join(FRAMES_DIR, 'frame_*.png')))
fourcc_cmp  = cv2.VideoWriter_fourcc(*'mp4v')
writer_cmp  = cv2.VideoWriter(COMPILED_OUT, fourcc_cmp, fps, (w, h))
for f in frame_files:
    img = cv2.imread(f)
    writer_cmp.write(img)
writer_cmp.release()
print(f"🎥 Compiled video saved to: {COMPILED_OUT}")
# Out:
# Running on cuda
#
# 0: 320x640 1 item, 11.5ms
# Speed: 2.1ms preprocess, 11.5ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 10.9ms
# Speed: 1.2ms preprocess, 10.9ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 5.1ms
# Speed: 1.1ms preprocess, 5.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 10.6ms
# Speed: 1.1ms preprocess, 10.6ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 4.9ms
# Speed: 1.3ms preprocess, 4.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.5ms
# Speed: 1.1ms preprocess, 5.5ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 6.8ms
# Speed: 1.1ms preprocess, 6.8ms inference, 5.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 11.0ms
# Speed: 1.4ms preprocess, 11.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 5.2ms
# Speed: 1.1ms preprocess, 5.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 8.8ms
# Speed: 1.2ms preprocess, 8.8ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 5.7ms
# Speed: 1.2ms preprocess, 5.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 5.0ms
# Speed: 1.2ms preprocess, 5.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 9.5ms
# Speed: 1.2ms preprocess, 9.5ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.2ms
# Speed: 1.1ms preprocess, 5.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.4ms
# Speed: 1.2ms preprocess, 5.4ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 6.2ms
# Speed: 1.2ms preprocess, 6.2ms inference, 4.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.1ms
# Speed: 1.2ms preprocess, 5.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.2ms
# Speed: 1.0ms preprocess, 5.2ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 6.3ms
# Speed: 1.1ms preprocess, 6.3ms inference, 4.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 6.5ms
# Speed: 1.2ms preprocess, 6.5ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 11.1ms
# Speed: 1.4ms preprocess, 11.1ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.3ms
# Speed: 2.1ms preprocess, 5.3ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.1ms
# Speed: 1.1ms preprocess, 5.1ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 9.7ms
# Speed: 1.1ms preprocess, 9.7ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 9.9ms
# Speed: 1.2ms preprocess, 9.9ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.1ms
# Speed: 1.0ms preprocess, 5.1ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.1ms
# Speed: 1.1ms preprocess, 5.1ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.6ms
# Speed: 1.3ms preprocess, 5.6ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 8.6ms
# Speed: 1.3ms preprocess, 8.6ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.2ms
# Speed: 1.1ms preprocess, 5.2ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 9.3ms
# Speed: 1.0ms preprocess, 9.3ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.1ms
# Speed: 1.2ms preprocess, 5.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.2ms
# Speed: 1.2ms preprocess, 5.2ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 8.7ms
# Speed: 1.1ms preprocess, 8.7ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.0ms
# Speed: 1.2ms preprocess, 5.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.4ms
# Speed: 1.2ms preprocess, 5.4ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 9.1ms
# Speed: 1.2ms preprocess, 9.1ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 7.5ms
# Speed: 1.3ms preprocess, 7.5ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.8ms
# Speed: 1.6ms preprocess, 5.8ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.4ms
# Speed: 1.2ms preprocess, 5.4ms inference, 5.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.3ms
# Speed: 1.3ms preprocess, 5.3ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.3ms
# Speed: 0.9ms preprocess, 5.3ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 9.5ms
# Speed: 1.2ms preprocess, 9.5ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.2ms
# Speed: 1.2ms preprocess, 5.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 7.7ms
# Speed: 1.3ms preprocess, 7.7ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.5ms
# Speed: 1.3ms preprocess, 5.5ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 8.6ms
# Speed: 1.2ms preprocess, 8.6ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.1ms
# Speed: 1.3ms preprocess, 5.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.2ms
# Speed: 1.2ms preprocess, 5.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 9.8ms
# Speed: 1.1ms preprocess, 9.8ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.1ms
# Speed: 1.1ms preprocess, 5.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 8.8ms
# Speed: 1.4ms preprocess, 8.8ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.9ms
# Speed: 5.1ms preprocess, 5.9ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 4.9ms
# Speed: 1.0ms preprocess, 4.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.1ms
# Speed: 1.3ms preprocess, 5.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 8.2ms
# Speed: 1.2ms preprocess, 8.2ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 4.9ms
# Speed: 1.1ms preprocess, 4.9ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 7.0ms
# Speed: 1.5ms preprocess, 7.0ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 10.7ms
# Speed: 1.4ms preprocess, 10.7ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 19.6ms
# Speed: 1.2ms preprocess, 19.6ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.6ms
# Speed: 11.4ms preprocess, 5.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 6.1ms
# Speed: 5.2ms preprocess, 6.1ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 13.3ms
# Speed: 1.2ms preprocess, 13.3ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 6.6ms
# Speed: 2.4ms preprocess, 6.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 9.3ms
# Speed: 1.4ms preprocess, 9.3ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 9.5ms
# Speed: 1.2ms preprocess, 9.5ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 7.3ms
# Speed: 1.3ms preprocess, 7.3ms inference, 5.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.4ms
# Speed: 1.2ms preprocess, 5.4ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.2ms
# Speed: 1.1ms preprocess, 5.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.0ms
# Speed: 1.1ms preprocess, 5.0ms inference, 5.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.0ms
# Speed: 1.1ms preprocess, 5.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.3ms
# Speed: 1.1ms preprocess, 5.3ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 4.8ms
# Speed: 1.1ms preprocess, 4.8ms inference, 5.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.0ms
# Speed: 1.1ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.5ms
# Speed: 3.7ms preprocess, 5.5ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 8.8ms
# Speed: 1.1ms preprocess, 8.8ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 4.9ms
# Speed: 1.1ms preprocess, 4.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.1ms
# Speed: 1.1ms preprocess, 5.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 8.9ms
# Speed: 1.1ms preprocess, 8.9ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.0ms
# Speed: 1.2ms preprocess, 5.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 4.9ms
# Speed: 1.2ms preprocess, 4.9ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 8.6ms
# Speed: 1.2ms preprocess, 8.6ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.2ms
# Speed: 1.3ms preprocess, 5.2ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 9.0ms
# Speed: 1.1ms preprocess, 9.0ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.1ms
# Speed: 1.0ms preprocess, 5.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.0ms
# Speed: 1.1ms preprocess, 5.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.5ms
# Speed: 1.2ms preprocess, 5.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.0ms
# Speed: 1.2ms preprocess, 5.0ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 9.9ms
# Speed: 1.1ms preprocess, 9.9ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.4ms
# Speed: 1.4ms preprocess, 5.4ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.1ms
# Speed: 1.2ms preprocess, 5.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 9.5ms
# Speed: 1.2ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.3ms
# Speed: 1.1ms preprocess, 5.3ms inference, 6.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.4ms
# Speed: 1.4ms preprocess, 5.4ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.1ms
# Speed: 1.2ms preprocess, 5.1ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.1ms
# Speed: 2.8ms preprocess, 5.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 4.8ms
# Speed: 1.1ms preprocess, 4.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.1ms
# Speed: 1.2ms preprocess, 5.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 10.5ms
# Speed: 1.2ms preprocess, 10.5ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 10.4ms
# Speed: 1.1ms preprocess, 10.4ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.0ms
# Speed: 1.2ms preprocess, 5.0ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 4.9ms
# Speed: 1.2ms preprocess, 4.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 9.1ms
# Speed: 1.2ms preprocess, 9.1ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.0ms
# Speed: 1.5ms preprocess, 5.0ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.2ms
# Speed: 1.2ms preprocess, 5.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.1ms
# Speed: 1.1ms preprocess, 5.1ms inference, 5.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 4.9ms
# Speed: 1.2ms preprocess, 4.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 4.9ms
# Speed: 1.0ms preprocess, 4.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 11.0ms
# Speed: 1.5ms preprocess, 11.0ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 4.9ms
# Speed: 1.3ms preprocess, 4.9ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 4.9ms
# Speed: 1.2ms preprocess, 4.9ms inference, 5.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.2ms
# Speed: 1.2ms preprocess, 5.2ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 4.9ms
# Speed: 1.2ms preprocess, 4.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 4.9ms
# Speed: 1.1ms preprocess, 4.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.3ms
# Speed: 1.2ms preprocess, 5.3ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 7.9ms
# Speed: 1.6ms preprocess, 7.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 9.1ms
# Speed: 1.2ms preprocess, 9.1ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 4.9ms
# Speed: 0.9ms preprocess, 4.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 4.9ms
# Speed: 1.2ms preprocess, 4.9ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.5ms
# Speed: 1.3ms preprocess, 5.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 8.3ms
# Speed: 1.2ms preprocess, 8.3ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 4.9ms
# Speed: 1.1ms preprocess, 4.9ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 6.5ms
# Speed: 1.4ms preprocess, 6.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 8.9ms
# Speed: 1.1ms preprocess, 8.9ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.0ms
# Speed: 1.2ms preprocess, 5.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 12.9ms
# Speed: 1.4ms preprocess, 12.9ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 6.1ms
# Speed: 1.3ms preprocess, 6.1ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.1ms
# Speed: 1.3ms preprocess, 5.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.0ms
# Speed: 1.7ms preprocess, 5.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.0ms
# Speed: 1.1ms preprocess, 5.0ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.2ms
# Speed: 1.2ms preprocess, 5.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.0ms
# Speed: 1.2ms preprocess, 5.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 8.6ms
# Speed: 1.0ms preprocess, 8.6ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.2ms
# Speed: 1.3ms preprocess, 5.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 5.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.4ms
# Speed: 1.2ms preprocess, 5.4ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 4.9ms
# Speed: 1.2ms preprocess, 4.9ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 9.0ms
# Speed: 1.1ms preprocess, 9.0ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 4.9ms
# Speed: 1.1ms preprocess, 4.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 4.9ms
# Speed: 1.1ms preprocess, 4.9ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 8.5ms
# Speed: 1.0ms preprocess, 8.5ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 4.7ms
# Speed: 1.2ms preprocess, 4.7ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.3ms
# Speed: 1.1ms preprocess, 5.3ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 12.0ms
# Speed: 4.9ms preprocess, 12.0ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 9.4ms
# Speed: 1.1ms preprocess, 9.4ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 4.7ms
# Speed: 1.2ms preprocess, 4.7ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.3ms
# Speed: 1.1ms preprocess, 5.3ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 8.6ms
# Speed: 1.0ms preprocess, 8.6ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 4.9ms
# Speed: 1.2ms preprocess, 4.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 7.5ms
# Speed: 1.3ms preprocess, 7.5ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.3ms
# Speed: 1.1ms preprocess, 5.3ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 10.5ms
# Speed: 1.2ms preprocess, 10.5ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.6ms
# Speed: 1.4ms preprocess, 5.6ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 9.6ms
# Speed: 1.6ms preprocess, 9.6ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.2ms
# Speed: 2.8ms preprocess, 5.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 8.0ms
# Speed: 2.7ms preprocess, 8.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 4.7ms
# Speed: 1.2ms preprocess, 4.7ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.1ms
# Speed: 1.2ms preprocess, 5.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 8.2ms
# Speed: 0.9ms preprocess, 8.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 4.9ms
# Speed: 1.1ms preprocess, 4.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.0ms
# Speed: 1.1ms preprocess, 5.0ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 9.3ms
# Speed: 1.2ms preprocess, 9.3ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 4.9ms
# Speed: 1.2ms preprocess, 4.9ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 4.9ms
# Speed: 1.2ms preprocess, 4.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 9.4ms
# Speed: 1.1ms preprocess, 9.4ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.3ms
# Speed: 1.2ms preprocess, 5.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 8.0ms
# Speed: 1.3ms preprocess, 8.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 10.0ms
# Speed: 1.2ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 4.7ms
# Speed: 1.2ms preprocess, 4.7ms inference, 5.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 31.7ms
# Speed: 1.2ms preprocess, 31.7ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 5.5ms
# Speed: 1.4ms preprocess, 5.5ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 11.5ms
# Speed: 1.3ms preprocess, 11.5ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 5.0ms
# Speed: 1.2ms preprocess, 5.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 5.2ms
# Speed: 1.3ms preprocess, 5.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 4.8ms
# Speed: 1.0ms preprocess, 4.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 5.1ms
# Speed: 1.2ms preprocess, 5.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.7ms
# Speed: 1.1ms preprocess, 8.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 4.8ms
# Speed: 1.0ms preprocess, 4.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.1ms
# Speed: 0.9ms preprocess, 5.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 11.9ms
# Speed: 1.4ms preprocess, 11.9ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 5.2ms
# Speed: 1.2ms preprocess, 5.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.2ms
# Speed: 1.0ms preprocess, 7.2ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.8ms
# Speed: 4.1ms preprocess, 5.8ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 19.1ms
# Speed: 1.5ms preprocess, 19.1ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 20.5ms
# Speed: 1.1ms preprocess, 20.5ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 13.1ms
# Speed: 1.2ms preprocess, 13.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 11.7ms
# Speed: 1.2ms preprocess, 11.7ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 4.9ms
# Speed: 3.2ms preprocess, 4.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 4.8ms
# Speed: 1.1ms preprocess, 4.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 12.0ms
# Speed: 1.4ms preprocess, 12.0ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 4.9ms
# Speed: 1.1ms preprocess, 4.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 5.0ms
# Speed: 1.2ms preprocess, 5.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 5.1ms
# Speed: 1.2ms preprocess, 5.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.9ms
# Speed: 1.1ms preprocess, 8.9ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.3ms
# Speed: 1.2ms preprocess, 7.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 5.1ms
# Speed: 1.3ms preprocess, 5.1ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.6ms
# Speed: 1.3ms preprocess, 9.6ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.1ms
# Speed: 1.2ms preprocess, 6.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 4.9ms
# Speed: 1.2ms preprocess, 4.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 9.5ms
# Speed: 1.2ms preprocess, 9.5ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 5.2ms
# Speed: 1.1ms preprocess, 5.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 5.1ms
# Speed: 1.0ms preprocess, 5.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 5.2ms
# Speed: 1.2ms preprocess, 5.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.3ms
# Speed: 1.2ms preprocess, 7.3ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 5.2ms
# Speed: 1.4ms preprocess, 5.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 5.4ms
# Speed: 1.4ms preprocess, 5.4ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 14.8ms
# Speed: 1.5ms preprocess, 14.8ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.8ms
# Speed: 1.1ms preprocess, 8.8ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.0ms
# Speed: 1.3ms preprocess, 6.0ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 5.0ms
# Speed: 3.5ms preprocess, 5.0ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 21.6ms
# Speed: 1.2ms preprocess, 21.6ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 6.0ms
# Speed: 6.8ms preprocess, 6.0ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 11.9ms
# Speed: 1.0ms preprocess, 11.9ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.2ms
# Speed: 1.1ms preprocess, 5.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 6.6ms
# Speed: 1.1ms preprocess, 6.6ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.2ms
# Speed: 3.0ms preprocess, 5.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 4.8ms
# Speed: 1.1ms preprocess, 4.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.3ms
# Speed: 1.1ms preprocess, 5.3ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 9.9ms
# Speed: 1.4ms preprocess, 9.9ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.2ms
# Speed: 1.2ms preprocess, 5.2ms inference, 5.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.0ms
# Speed: 1.2ms preprocess, 5.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 8.5ms
# Speed: 1.5ms preprocess, 8.5ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 9.1ms
# Speed: 1.0ms preprocess, 9.1ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.0ms
# Speed: 1.2ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.1ms
# Speed: 1.1ms preprocess, 5.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 4.9ms
# Speed: 3.9ms preprocess, 4.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.1ms
# Speed: 1.1ms preprocess, 5.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 7.0ms
# Speed: 1.5ms preprocess, 7.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.1ms
# Speed: 3.8ms preprocess, 5.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 12.6ms
# Speed: 1.4ms preprocess, 12.6ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 4.9ms
# Speed: 1.2ms preprocess, 4.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.2ms
# Speed: 1.1ms preprocess, 6.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.0ms
# Speed: 1.2ms preprocess, 5.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 8.4ms
# Speed: 1.2ms preprocess, 8.4ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 5.1ms
# Speed: 1.2ms preprocess, 5.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 10.2ms
# Speed: 1.3ms preprocess, 10.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 5.7ms
# Speed: 1.3ms preprocess, 5.7ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 5.2ms
# Speed: 1.2ms preprocess, 5.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 10.1ms
# Speed: 6.4ms preprocess, 10.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 5.2ms
# Speed: 1.4ms preprocess, 5.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.5ms
# Speed: 1.5ms preprocess, 6.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.0ms
# Speed: 4.5ms preprocess, 5.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 7.3ms
# Speed: 1.4ms preprocess, 7.3ms inference, 5.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 4.9ms
# Speed: 1.1ms preprocess, 4.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.2ms
# Speed: 1.2ms preprocess, 5.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 4.8ms
# Speed: 1.0ms preprocess, 4.8ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 10.8ms
# Speed: 1.4ms preprocess, 10.8ms inference, 5.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 10.6ms
# Speed: 1.4ms preprocess, 10.6ms inference, 4.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 items, 4.9ms
# Speed: 1.1ms preprocess, 4.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 items, 4.9ms
# Speed: 1.2ms preprocess, 4.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 9.8ms
# Speed: 1.3ms preprocess, 9.8ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.0ms
# Speed: 1.1ms preprocess, 5.0ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 4.9ms
# Speed: 1.1ms preprocess, 4.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.9ms
# Speed: 1.1ms preprocess, 8.9ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 items, 4.9ms
# Speed: 1.2ms preprocess, 4.9ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 items, 5.0ms
# Speed: 1.1ms preprocess, 5.0ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 items, 9.4ms
# Speed: 1.0ms preprocess, 9.4ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 7.8ms
# Speed: 1.4ms preprocess, 7.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 11.1ms
# Speed: 1.2ms preprocess, 11.1ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.5ms
# Speed: 2.5ms preprocess, 5.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 4.9ms
# Speed: 3.1ms preprocess, 4.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 11.9ms
# Speed: 1.4ms preprocess, 11.9ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.2ms
# Speed: 1.2ms preprocess, 5.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.2ms
# Speed: 1.2ms preprocess, 5.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 12.8ms
# Speed: 2.9ms preprocess, 12.8ms inference, 3.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 12.1ms
# Speed: 1.7ms preprocess, 12.1ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 11.3ms
# Speed: 1.6ms preprocess, 11.3ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 6.0ms
# Speed: 1.2ms preprocess, 6.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.8ms
# Speed: 3.7ms preprocess, 5.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 8.7ms
# Speed: 1.1ms preprocess, 8.7ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 7.2ms
# Speed: 1.4ms preprocess, 7.2ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.3ms
# Speed: 1.3ms preprocess, 5.3ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 items, 8.5ms
# Speed: 1.1ms preprocess, 8.5ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 6.6ms
# Speed: 1.4ms preprocess, 6.6ms inference, 5.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 4.9ms
# Speed: 1.2ms preprocess, 4.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.1ms
# Speed: 1.1ms preprocess, 5.1ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 4.8ms
# Speed: 1.1ms preprocess, 4.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 4.9ms
# Speed: 1.2ms preprocess, 4.9ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.1ms
# Speed: 1.1ms preprocess, 5.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.1ms
# Speed: 1.1ms preprocess, 5.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.1ms
# Speed: 1.4ms preprocess, 5.1ms inference, 5.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.0ms
# Speed: 1.3ms preprocess, 5.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 9.2ms
# Speed: 1.1ms preprocess, 9.2ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 4.8ms
# Speed: 1.1ms preprocess, 4.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.2ms
# Speed: 1.3ms preprocess, 5.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 4.8ms
# Speed: 1.0ms preprocess, 4.8ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 12.9ms
# Speed: 2.2ms preprocess, 12.9ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 13.1ms
# Speed: 3.2ms preprocess, 13.1ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 4.9ms
# Speed: 1.2ms preprocess, 4.9ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 4.9ms
# Speed: 1.1ms preprocess, 4.9ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 8.8ms
# Speed: 1.2ms preprocess, 8.8ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 4.9ms
# Speed: 1.1ms preprocess, 4.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 10.7ms
# Speed: 1.1ms preprocess, 10.7ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.2ms
# Speed: 1.2ms preprocess, 5.2ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.3ms
# Speed: 3.8ms preprocess, 5.3ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 4.9ms
# Speed: 1.2ms preprocess, 4.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.1ms
# Speed: 1.3ms preprocess, 5.1ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.1ms
# Speed: 4.9ms preprocess, 5.1ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 8.7ms
# Speed: 1.2ms preprocess, 8.7ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 4.9ms
# Speed: 1.2ms preprocess, 4.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.2ms
# Speed: 1.1ms preprocess, 5.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 8.7ms
# Speed: 1.0ms preprocess, 8.7ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 4.7ms
# Speed: 1.1ms preprocess, 4.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.1ms
# Speed: 1.4ms preprocess, 5.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 8.8ms
# Speed: 1.0ms preprocess, 8.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.9ms
# Speed: 1.2ms preprocess, 5.9ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.1ms
# Speed: 1.2ms preprocess, 5.1ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.3ms
# Speed: 1.3ms preprocess, 5.3ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 4.8ms
# Speed: 1.1ms preprocess, 4.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.1ms
# Speed: 1.0ms preprocess, 5.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 9.9ms
# Speed: 27.5ms preprocess, 9.9ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.3ms
# Speed: 1.2ms preprocess, 5.3ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.2ms
# Speed: 1.3ms preprocess, 5.2ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 8.4ms
# Speed: 1.1ms preprocess, 8.4ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 4.8ms
# Speed: 1.1ms preprocess, 4.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 4.7ms
# Speed: 1.4ms preprocess, 4.7ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 items, 9.1ms
# Speed: 1.0ms preprocess, 9.1ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 items, 4.9ms
# Speed: 1.2ms preprocess, 4.9ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 items, 5.8ms
# Speed: 1.3ms preprocess, 5.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.2ms
# Speed: 3.8ms preprocess, 5.2ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 items, 5.0ms
# Speed: 1.1ms preprocess, 5.0ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.3ms
# Speed: 1.0ms preprocess, 5.3ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.8ms
# Speed: 3.3ms preprocess, 5.8ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 12.2ms
# Speed: 1.4ms preprocess, 12.2ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.0ms
# Speed: 1.2ms preprocess, 5.0ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.1ms
# Speed: 1.3ms preprocess, 5.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 8.7ms
# Speed: 1.4ms preprocess, 8.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.2ms
# Speed: 0.9ms preprocess, 5.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 20.3ms
# Speed: 8.9ms preprocess, 20.3ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.3ms
# Speed: 4.0ms preprocess, 5.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.0ms
# Speed: 1.1ms preprocess, 5.0ms inference, 9.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.4ms
# Speed: 1.0ms preprocess, 5.4ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.2ms
# Speed: 1.3ms preprocess, 5.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 8.6ms
# Speed: 1.2ms preprocess, 8.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.1ms
# Speed: 0.8ms preprocess, 5.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.2ms
# Speed: 1.0ms preprocess, 5.2ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.0ms
# Speed: 1.2ms preprocess, 5.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 items, 5.8ms
# Speed: 1.3ms preprocess, 5.8ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.1ms
# Speed: 1.2ms preprocess, 5.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 4.9ms
# Speed: 2.3ms preprocess, 4.9ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 4.7ms
# Speed: 1.0ms preprocess, 4.7ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.1ms
# Speed: 1.1ms preprocess, 5.1ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 4.9ms
# Speed: 1.0ms preprocess, 4.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 7.5ms
# Speed: 0.8ms preprocess, 7.5ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 6.5ms
# Speed: 1.3ms preprocess, 6.5ms inference, 4.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 4.9ms
# Speed: 1.1ms preprocess, 4.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 6.4ms
# Speed: 1.3ms preprocess, 6.4ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 7.8ms
# Speed: 1.1ms preprocess, 7.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 4.6ms
# Speed: 1.0ms preprocess, 4.6ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.2ms
# Speed: 1.1ms preprocess, 5.2ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 8.2ms
# Speed: 0.9ms preprocess, 8.2ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 4.8ms
# Speed: 1.1ms preprocess, 4.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.2ms
# Speed: 1.1ms preprocess, 5.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 12.5ms
# Speed: 1.1ms preprocess, 12.5ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 4.7ms
# Speed: 1.0ms preprocess, 4.7ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 9.5ms
# Speed: 1.2ms preprocess, 9.5ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.4ms
# Speed: 3.9ms preprocess, 5.4ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.1ms
# Speed: 1.0ms preprocess, 5.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 items, 5.1ms
# Speed: 1.0ms preprocess, 5.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 7.5ms
# Speed: 1.1ms preprocess, 7.5ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 6.3ms
# Speed: 1.2ms preprocess, 6.3ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 4.9ms
# Speed: 1.1ms preprocess, 4.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 10.6ms
# Speed: 1.1ms preprocess, 10.6ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 4.9ms
# Speed: 1.0ms preprocess, 4.9ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.5ms
# Speed: 0.9ms preprocess, 5.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 7.3ms
# Speed: 1.1ms preprocess, 7.3ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 4.9ms
# Speed: 1.0ms preprocess, 4.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 4.9ms
# Speed: 1.1ms preprocess, 4.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 7.4ms
# Speed: 1.0ms preprocess, 7.4ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 5.4ms
# Speed: 1.1ms preprocess, 5.4ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 7.2ms
# Speed: 1.0ms preprocess, 7.2ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 items, 4.7ms
# Speed: 1.0ms preprocess, 4.7ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# ...
#
# 0: 320x640 (no detections), 6.4ms
# Speed: 1.1ms preprocess, 6.4ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.1ms
# Speed: 1.2ms preprocess, 8.1ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 5.0ms
# Speed: 1.2ms preprocess, 5.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 5.6ms
# Speed: 1.1ms preprocess, 5.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.3ms
# Speed: 1.5ms preprocess, 8.3ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 4.9ms
# Speed: 1.2ms preprocess, 4.9ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 5.4ms
# Speed: 1.1ms preprocess, 5.4ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 4.9ms
# Speed: 1.2ms preprocess, 4.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 5.9ms
# Speed: 1.1ms preprocess, 5.9ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.3ms
# Speed: 1.3ms preprocess, 5.3ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 5.5ms
# Speed: 2.7ms preprocess, 5.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 5.0ms
# Speed: 1.1ms preprocess, 5.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.4ms
# Speed: 1.4ms preprocess, 8.4ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 5.1ms
# Speed: 2.1ms preprocess, 5.1ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 5.2ms
# Speed: 1.1ms preprocess, 5.2ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.1ms
# Speed: 1.2ms preprocess, 8.1ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 5.3ms
# Speed: 1.2ms preprocess, 5.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.4ms
# Speed: 1.6ms preprocess, 8.4ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 5.2ms
# Speed: 1.1ms preprocess, 5.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 5.3ms
# Speed: 0.9ms preprocess, 5.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 5.1ms
# Speed: 1.2ms preprocess, 5.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 10.7ms
# Speed: 1.2ms preprocess, 10.7ms inference, 3.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 5.3ms
# Speed: 1.0ms preprocess, 5.3ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 13.2ms
# Speed: 1.1ms preprocess, 13.2ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 5.8ms
# Speed: 1.3ms preprocess, 5.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 6.0ms
# Speed: 1.2ms preprocess, 6.0ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 5.1ms
# Speed: 1.2ms preprocess, 5.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 5.1ms
# Speed: 1.3ms preprocess, 5.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 5.1ms
# Speed: 1.1ms preprocess, 5.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 4.9ms
# Speed: 1.2ms preprocess, 4.9ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.0ms
# Speed: 1.2ms preprocess, 5.0ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 19.0ms
# Speed: 8.5ms preprocess, 19.0ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.2ms
# Speed: 1.2ms preprocess, 5.2ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 4.9ms
# Speed: 1.3ms preprocess, 4.9ms inference, 7.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 6.3ms
# Speed: 1.4ms preprocess, 6.3ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 4.8ms
# Speed: 1.5ms preprocess, 4.8ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.2ms
# Speed: 1.2ms preprocess, 5.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 6.9ms
# Speed: 1.3ms preprocess, 6.9ms inference, 4.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.8ms
# Speed: 1.1ms preprocess, 5.8ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 6.2ms
# Speed: 1.2ms preprocess, 6.2ms inference, 4.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 9.4ms
# Speed: 1.2ms preprocess, 9.4ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.4ms
# Speed: 1.4ms preprocess, 5.4ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.3ms
# Speed: 1.1ms preprocess, 5.3ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.7ms
# Speed: 1.2ms preprocess, 5.7ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 7.0ms
# Speed: 1.5ms preprocess, 7.0ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 8.1ms
# Speed: 1.4ms preprocess, 8.1ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.0ms
# Speed: 1.1ms preprocess, 5.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 10.1ms
# Speed: 1.2ms preprocess, 10.1ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.1ms
# Speed: 1.2ms preprocess, 5.1ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 9.6ms
# Speed: 1.2ms preprocess, 9.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 10.3ms
# Speed: 1.5ms preprocess, 10.3ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 4.8ms
# Speed: 1.0ms preprocess, 4.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.5ms
# Speed: 1.5ms preprocess, 5.5ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 6.2ms
# Speed: 1.3ms preprocess, 6.2ms inference, 5.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.0ms
# Speed: 1.2ms preprocess, 5.0ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 20.4ms
# Speed: 8.0ms preprocess, 20.4ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 7.0ms
# Speed: 1.3ms preprocess, 7.0ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.5ms
# Speed: 3.6ms preprocess, 5.5ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 8.6ms
# Speed: 1.1ms preprocess, 8.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.0ms
# Speed: 1.2ms preprocess, 5.0ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 4.9ms
# Speed: 1.2ms preprocess, 4.9ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.2ms
# Speed: 1.2ms preprocess, 5.2ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 8.1ms
# Speed: 1.2ms preprocess, 8.1ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.2ms
# Speed: 1.3ms preprocess, 5.2ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 6.1ms
# Speed: 1.1ms preprocess, 6.1ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.0ms
# Speed: 1.3ms preprocess, 5.0ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 10.9ms
# Speed: 1.5ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 12.0ms
# Speed: 1.6ms preprocess, 12.0ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.5ms
# Speed: 3.2ms preprocess, 5.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 9.5ms
# Speed: 1.2ms preprocess, 9.5ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 7.1ms
# Speed: 1.8ms preprocess, 7.1ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 11.0ms
# Speed: 1.3ms preprocess, 11.0ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.2ms
# Speed: 1.0ms preprocess, 5.2ms inference, 5.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 4.9ms
# Speed: 1.2ms preprocess, 4.9ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 4.8ms
# Speed: 1.3ms preprocess, 4.8ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 6.4ms
# Speed: 1.2ms preprocess, 6.4ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 4.8ms
# Speed: 1.3ms preprocess, 4.8ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 8.3ms
# Speed: 1.4ms preprocess, 8.3ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 7.6ms
# Speed: 1.9ms preprocess, 7.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.8ms
# Speed: 1.1ms preprocess, 5.8ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.3ms
# Speed: 1.5ms preprocess, 5.3ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.4ms
# Speed: 2.9ms preprocess, 5.4ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 8.5ms
# Speed: 1.1ms preprocess, 8.5ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.0ms
# Speed: 1.5ms preprocess, 5.0ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 7.8ms
# Speed: 1.2ms preprocess, 7.8ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.3ms
# Speed: 1.2ms preprocess, 5.3ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 4.9ms
# Speed: 1.1ms preprocess, 4.9ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.0ms
# Speed: 1.2ms preprocess, 5.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 4.9ms
# Speed: 1.2ms preprocess, 4.9ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.3ms
# Speed: 1.2ms preprocess, 5.3ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 7.6ms
# Speed: 1.6ms preprocess, 7.6ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 8.6ms
# Speed: 1.2ms preprocess, 8.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.2ms
# Speed: 1.2ms preprocess, 5.2ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 4.9ms
# Speed: 1.2ms preprocess, 4.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 8.0ms
# Speed: 1.4ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.2ms
# Speed: 1.2ms preprocess, 5.2ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 7.3ms
# Speed: 1.4ms preprocess, 7.3ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 4.9ms
# Speed: 1.2ms preprocess, 4.9ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.3ms
# Speed: 1.1ms preprocess, 5.3ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.0ms
# Speed: 1.2ms preprocess, 5.0ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.3ms
# Speed: 1.5ms preprocess, 5.3ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 9.6ms
# Speed: 1.3ms preprocess, 9.6ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.4ms
# Speed: 1.0ms preprocess, 5.4ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 7.3ms
# Speed: 2.7ms preprocess, 7.3ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.8ms
# Speed: 4.0ms preprocess, 5.8ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 5.3ms
# Speed: 1.2ms preprocess, 5.3ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.2ms
# Speed: 1.3ms preprocess, 5.2ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.3ms
# Speed: 1.2ms preprocess, 5.3ms inference, 6.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.0ms
# Speed: 1.2ms preprocess, 5.0ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.0ms
# Speed: 1.1ms preprocess, 5.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 10.6ms
# Speed: 1.1ms preprocess, 10.6ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.0ms
# Speed: 1.3ms preprocess, 5.0ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.0ms
# Speed: 1.3ms preprocess, 5.0ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 8.4ms
# Speed: 1.0ms preprocess, 8.4ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 19.2ms
# Speed: 1.2ms preprocess, 19.2ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 10.9ms
# Speed: 1.2ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 9.0ms
# Speed: 1.6ms preprocess, 9.0ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 4.9ms
# Speed: 1.0ms preprocess, 4.9ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 item, 5.3ms
# Speed: 1.2ms preprocess, 5.3ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 5.4ms
# Speed: 3.0ms preprocess, 5.4ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 4.8ms
# Speed: 1.1ms preprocess, 4.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
# ✅ Done: 1633 frames in 37.4s → 43.6 FPS
# Final counts → Entry: 2, Exit: 3
# 🎥 Compiled video saved to: C:\Users\Himanshu\Desktop\yolov11n\outputs\compiled_video.mp4
